# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv',usecols=['GarageQual','FireplaceQu','SalePrice'])

# %%
df.head()
# Out:
#   FireplaceQu GarageQual  SalePrice
# 0         NaN         TA     208500
# 1          TA         TA     181500
# 2          TA         TA     223500
# 3          Gd         TA     140000
# 4          TA         TA     250000

# %%
df.isnull().mean()*100
# Out:
# FireplaceQu    47.260274
# GarageQual      5.547945
# SalePrice       0.000000
# dtype: float64

# %%
df['GarageQual'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='GarageQual'>

# %%
df['GarageQual'].mode()
# Out:
# 0    TA
# Name: GarageQual, dtype: object

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

df[df['GarageQual']=='TA']['SalePrice'].plot(kind='kde', ax=ax)

df[df['GarageQual'].isnull()]['SalePrice'].plot(kind='kde', ax=ax, color='red')

lines, labels = ax.get_legend_handles_labels()
labels = ['Houses with TA', 'Houses with NA']
ax.legend(lines, labels, loc='best')

plt.title('GarageQual')
# Out:
# Text(0.5, 1.0, 'GarageQual')

# %%
temp = df[df['GarageQual']=='TA']['SalePrice']

# %%
df['GarageQual'].fillna('TA', inplace=True)

# %%
df['GarageQual'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='GarageQual'>

# %%
fig = plt.figure()
ax = fig.add_subplot(111)


temp.plot(kind='kde', ax=ax)

# distribution of the variable after imputation
df[df['GarageQual'] == 'TA']['SalePrice'].plot(kind='kde', ax=ax, color='red')

lines, labels = ax.get_legend_handles_labels()
labels = ['Original variable', 'Imputed variable']
ax.legend(lines, labels, loc='best')

# add title
plt.title('GarageQual')
# Out:
# Text(0.5, 1.0, 'GarageQual')

# %%
df['FireplaceQu'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='FireplaceQu'>

# %%
df['FireplaceQu'].mode()
# Out:
# 0    Gd
# Name: FireplaceQu, dtype: object

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

df[df['FireplaceQu']=='Gd']['SalePrice'].plot(kind='kde', ax=ax)

df[df['FireplaceQu'].isnull()]['SalePrice'].plot(kind='kde', ax=ax, color='red')

lines, labels = ax.get_legend_handles_labels()
labels = ['Houses with Gd', 'Houses with NA']
ax.legend(lines, labels, loc='best')

plt.title('FireplaceQu')
# Out:
# Text(0.5, 1.0, 'FireplaceQu')

# %%
temp=df[df['FireplaceQu']=='GD']['SalePrice']

# %%
df['FireplaceQu'].fillna('Gd',inplace=True)

# %%
df['FireplaceQu'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='FireplaceQu'>

# %%
fig = plt.figure()
ax = fig.add_subplot(111)


temp.plot(kind='kde', ax=ax)

# distribution of the variable after imputation
df[df['FireplaceQu'] == 'Gd']['SalePrice'].plot(kind='kde', ax=ax, color='red')

lines, labels = ax.get_legend_handles_labels()
labels = ['Original variable', 'Imputed variable']
ax.legend(lines, labels, loc='best')

# add title
plt.title('FireplaceQu')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 5
#       1 fig = plt.figure()
#       2 ax = fig.add_subplot(111)
# ----> 5 temp.plot(kind='kde', ax=ax)
#       7 # distribution of the variable after imputation
#       8 df[df['FireplaceQu'] == 'Gd']['SalePrice'].plot(kind='kde', ax=ax, color='red')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\plotting\_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     972             label_name = label_kw or data.columns
#     973             data.columns = label_name
# --> 975 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:448, in MPLPlot.generate(self)
#     446 self._compute_plot_data()
#     447 self._setup_subplots()
# --> 448 self._make_plot()
#     449 self._add_table()
#     450 self._make_legend()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\hist.py:140, in HistPlot._make_plot(self)
#     137 if style is not None:
#     138     kwds["style"] = style
# --> 140 kwds = self._make_plot_keywords(kwds, y)
#     142 # the bins is multi-dimension array now and each plot need only 1-d and
#     143 # when by is applied, label should be columns that are grouped
#     144 if self.by is not None:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\hist.py:259, in KdePlot._make_plot_keywords(self, kwds, y)
#     257 def _make_plot_keywords(self, kwds, y):
#     258     kwds["bw_method"] = self.bw_method
# --> 259     kwds["ind"] = self._get_ind(y)
#     260     return kwds
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\hist.py:219, in KdePlot._get_ind(self, y)
#     216 def _get_ind(self, y):
#     217     if self.ind is None:
#     218         # np.nanmax() and np.nanmin() ignores the missing values
# --> 219         sample_range = np.nanmax(y) - np.nanmin(y)
#     220         ind = np.linspace(
#     221             np.nanmin(y) - 0.5 * sample_range,
#     222             np.nanmax(y) + 0.5 * sample_range,
#     223             1000,
#     224         )
#     225     elif is_integer(self.ind):
#
# File <__array_function__ internals>:200, in nanmax(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\nanfunctions.py:476, in nanmax(a, axis, out, keepdims, initial, where)
#     471     kwargs['where'] = where
#     473 if type(a) is np.ndarray and a.dtype != np.object_:
#     474     # Fast, but not safe for subclasses of ndarray, or object arrays,
#     475     # which do not implement isnan (gh-9009), or fmax correctly (gh-8975)
# --> 476     res = np.fmax.reduce(a, axis=axis, out=out, **kwargs)
#     477     if np.isnan(res).any():
#     478         warnings.warn("All-NaN slice encountered", RuntimeWarning,
#     479                       stacklevel=3)
#
# ValueError: zero-size array to reduction operation fmax which has no identity

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df.drop(columns=['SalePrice']),df['SalePrice'],test_size=0.2)

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy='most_frequent')

# %%
X_train = imputer.fit_transform(X_train)
X_test = imputer.transform(X_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(

# %%
imputer.statistics_
# Out:
# array(['Gd', 'TA'], dtype=object)
