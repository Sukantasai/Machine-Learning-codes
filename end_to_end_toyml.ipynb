# %% [markdown]
# <a href="https://colab.research.google.com/github/Sukantasai/Sukantasai/blob/main/end_to_end_toyml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Unnamed: 0'].plot(kind='hist', bins=20, title='Unnamed: 0')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['cgpa'].plot(kind='hist', bins=20, title='cgpa')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['iq'].plot(kind='hist', bins=20, title='iq')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['placement'].plot(kind='hist', bins=20, title='placement')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='Unnamed: 0', y='cgpa', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='cgpa', y='iq', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='iq', y='placement', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Unnamed: 0']
#   ys = series['cgpa']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_7.sort_values('Unnamed: 0', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('cgpa')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Unnamed: 0']
#   ys = series['iq']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_8.sort_values('Unnamed: 0', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('iq')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Unnamed: 0']
#   ys = series['placement']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('Unnamed: 0', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('placement')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Unnamed: 0']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Unnamed: 0'}, axis=1)
#               .sort_values('Unnamed: 0', ascending=True))
#   xs = counted['Unnamed: 0']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('Unnamed: 0', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_11['Unnamed: 0'].plot(kind='line', figsize=(8, 4), title='Unnamed: 0')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_12['cgpa'].plot(kind='line', figsize=(8, 4), title='cgpa')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['iq'].plot(kind='line', figsize=(8, 4), title='iq')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['placement'].plot(kind='line', figsize=(8, 4), title='placement')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.2 KB

# %%
df.shape
# Out:
# (100, 4)

# %%
df=df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'])

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
x=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 6    5.7  143.0
# 97   6.7  182.0
# 45   6.0   66.0
# 29   7.0  112.0
# 75   4.8  169.0
# ..   ...    ...
# 17   3.3  183.0
# 26   7.0  199.0
# 87   5.7  132.0
# 68   4.0   75.0
# 19   5.2  132.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 6     0
# 97    1
# 45    1
# 29    1
# 75    0
#      ..
# 17    0
# 26    1
# 87    1
# 68    0
# 19    0
# Name: placement, Length: 90, dtype: int64

# %%
x_test
# Out:
#     cgpa     iq
# 71   6.1  132.0
# 86   5.1  128.0
# 88   4.4  149.0
# 94   4.7   52.0
# 38   6.5  160.0
# 23   4.7   87.0
# 74   6.7  154.0
# 34   4.8  163.0
# 16   5.2  224.0
# 14   6.1  103.0

# %%
y_test
# Out:
# 71    1
# 86    0
# 88    0
# 94    0
# 38    1
# 23    0
# 74    1
# 34    0
# 16    0
# 14    0
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[-0.30645055,  0.53220913],
#        [ 0.56086232,  1.53438404],
#        [-0.04625669, -1.44644391],
#        [ 0.82105619, -0.26439144],
#        [-1.08703213,  1.20032574],
#        [-0.04625669,  0.04397007],
#        [-1.26049471,  0.60929951],
#        [-1.08703213, -0.26439144],
#        [ 0.0404746 , -1.4721407 ],
#        [-0.56664441,  0.42942196],
#        [ 0.0404746 ,  0.86626743],
#        [-1.86761372, -0.34148182],
#        [ 1.25471262,  0.91766102],
#        [ 1.34144391, -0.85541768],
#        [ 0.38739975, -2.1916509 ],
#        [-1.00030085,  0.73778347],
#        [ 0.7343249 ,  0.42942196],
#        [-0.91356956, -0.80402409],
#        [ 0.0404746 , -1.06099202],
#        [ 0.64759361, -0.26439144],
#        [ 0.30066846, -0.16160427],
#        [ 0.21393718,  0.14675724],
#        [-1.52068857,  1.99692631],
#        [-0.74010699,  0.9947514 ],
#        [-0.30645055,  0.45511875],
#        [ 0.7343249 , -0.67554013],
#        [-0.13298797, -0.4185722 ],
#        [-0.56664441, -0.39287541],
#        [-0.30645055,  1.20032574],
#        [-1.78088243, -0.57275296],
#        [-1.00030085,  0.30093799],
#        [-1.00030085,  0.84057064],
#        [-1.08703213,  0.48081554],
#        [-1.17376342, -0.03312031],
#        [-0.04625669, -1.98607655],
#        [-0.82683827,  1.38020329],
#        [-0.04625669, -0.52135937],
#        [ 0.30066846,  0.48081554],
#        [ 0.90778747,  0.73778347],
#        [-0.82683827, -1.44644391],
#        [ 0.64759361, -0.82972088],
#        [-0.91356956, -0.11021069],
#        [ 0.38739975, -0.82972088],
#        [ 0.7343249 ,  0.40372516],
#        [-0.74010699, -0.82972088],
#        [-0.21971926,  1.12323536],
#        [-1.00030085,  1.89413914],
#        [ 0.47413104, -0.0588171 ],
#        [ 1.34144391,  0.14675724],
#        [ 0.82105619,  1.35450649],
#        [ 0.21393718,  0.12106045],
#        [-2.21453887,  2.84492047],
#        [ 1.16798134,  0.24954441],
#        [-1.00030085, -1.57492787],
#        [ 1.08125005,  0.37802837],
#        [ 0.12720589, -0.23869465],
#        [ 0.82105619, -1.49783749],
#        [ 1.25471262,  0.19815082],
#        [-0.6533757 , -0.03312031],
#        [ 1.51490649, -0.21299786],
#        [ 1.08125005, -0.16160427],
#        [ 1.08125005, -1.85759259],
#        [ 1.77510035,  1.12323536],
#        [-0.6533757 , -0.21299786],
#        [ 0.90778747, -1.90898618],
#        [ 0.64759361,  0.48081554],
#        [-0.04625669,  0.68638988],
#        [-0.56664441, -0.21299786],
#        [-0.74010699, -0.31578503],
#        [-0.91356956, -1.52353429],
#        [ 1.25471262, -1.57492787],
#        [ 0.82105619,  0.42942196],
#        [ 0.47413104,  0.40372516],
#        [-0.56664441,  0.32663479],
#        [-1.43395728, -2.06316693],
#        [-1.00030085, -0.0588171 ],
#        [ 1.94856292,  1.17462895],
#        [ 1.68836906, -1.1123856 ],
#        [ 0.64759361,  0.01827327],
#        [ 2.1220255 , -0.0588171 ],
#        [ 1.77510035,  0.68638988],
#        [ 1.08125005, -0.93250805],
#        [ 0.21393718, -0.49566258],
#        [ 0.38739975,  0.19815082],
#        [-0.21971926,  0.50651234],
#        [-2.38800144,  1.56008084],
#        [ 0.82105619,  1.97122952],
#        [-0.30645055,  0.24954441],
#        [-1.78088243, -1.21517277],
#        [-0.74010699,  0.24954441]])

# %%
x_test=scaler.transform(x_test)

# %%
x_test
# Out:
# array([[ 0.0404746 ,  0.24954441],
#        [-0.82683827,  0.14675724],
#        [-1.43395728,  0.68638988],
#        [-1.17376342, -1.80619901],
#        [ 0.38739975,  0.9690546 ],
#        [-1.17376342, -0.90681126],
#        [ 0.56086232,  0.81487385],
#        [-1.08703213,  1.04614498],
#        [-0.74010699,  2.61364934],
#        [ 0.0404746 , -0.49566258]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf=LogisticRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=clf.predict(x_test)

# %%
y_test
# Out:
# 71    1
# 86    0
# 88    0
# 94    0
# 38    1
# 23    0
# 74    1
# 34    0
# 16    0
# 14    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train,y_train.values,clf=clf,legend=2)
# Out:
# <Axes: >
