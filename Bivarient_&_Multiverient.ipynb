# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
titanic=pd.read_csv('tested.csv')

# %%
zomato=pd.read_csv('zomato.csv')

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
titanic.sample(9)
# Out:
#      PassengerId  Survived  Pclass  \
# 410         1302         1       3
# 296         1188         1       2
# 133         1025         0       3
# 132         1024         1       3
# 292         1184         0       3
# 177         1069         0       1
# 364         1256         1       1
# 37           929         1       3
# 331         1223         0       1
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 410                        Naughton, Miss. Hannah  female   NaN      0      0
# 296                         Laroche, Miss. Louise  female   1.0      1      2
# 133                         Thomas, Mr. Charles P    male   NaN      1      0
# 132                 Lefebre, Mrs. Frank (Frances)  female   NaN      0      4
# 292                             Nasr, Mr. Mustafa    male   NaN      0      0
# 177               Stengel, Mr. Charles Emil Henry    male  54.0      1      0
# ...

# %%
zomato.sample(1)
# Out:
#                                                     url  \
# 3034  https://www.zomato.com/bangalore/hatti-punjab-...
#
#                                                 address             name  \
# 3034  Shop 200/3, Laxmi Towers, Near South End Circl...  Hatti Punjab Di
#
#      online_order book_table rate  votes           phone   location  \
# 3034           No         No  NaN      0  +91 8884444038  Jayanagar
#
#           rest_type dish_liked               cuisines  \
# 3034  Casual Dining        NaN  North Indian, Chinese
#
#      approx_cost(for two people) reviews_list menu_item listed_in(type)  \
# 3034                         600           []        []        Delivery
#
#      listed_in(city)
# 3034    Basavanagudi

# %%
zomato=pd.read_csv('zomato.csv',usecols=['book_table','online_order','votes'])

# %%
zomato
# Out:
#       online_order book_table  votes
# 0              Yes        Yes    775
# 1              Yes         No    787
# 2              Yes         No    918
# 3               No         No     88
# 4               No         No    166
# ...            ...        ...    ...
# 51712           No         No     27
# 51713           No         No      0
# 51714           No         No      0
# 51715           No        Yes    236
# 51716           No         No     13
#
# [51717 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
sns.boxplot(titanic['Fare'])
# Out:
# <Axes: >

# %%
sns.boxplot(titanic['Age'])
# Out:
# <Axes: >

# %%
sns.boxplot(titanic['Parch'])
# Out:
# <Axes: >

# %%
df = pd.DataFrame({'Pclass': titanic['Pclass'], 'Age': titanic['Age']})
sns.barplot(x='Pclass', y='Age', data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.jointplot(x='Pclass', y='Age', data=titanic)

# %%
df = pd.DataFrame({'Sex': titanic['Sex'], 'Age': titanic['Age']})
sns.boxplot(x='Sex', y='Age', data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.distplot(titanic[titanic['Survived']==0]['Age'])
sns.distplot(titanic[titanic['Survived']==1]['Age'])
# Out:
# C:\Users\SUKANTA SAI\AppData\Local\Temp\ipykernel_11196\3286402471.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic[titanic['Survived']==0]['Age'])
# C:\Users\SUKANTA SAI\AppData\Local\Temp\ipykernel_11196\3286402471.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.heatmap(pd.crosstab(titanic['Pclass'],titanic['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
sns.clustermap(pd.crosstab(titanic['Parch'],titanic['Survived']))

# %%
sns.clustermap(pd.crosstab(titanic['Survived'],titanic['Embarked']))

# %%
flower=pd.read_csv('IRIS.csv')

# %%
flower.sample(8)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          species
# 70            5.9          3.2           4.8          1.8  Iris-versicolor
# 92            5.8          2.6           4.0          1.2  Iris-versicolor
# 48            5.3          3.7           1.5          0.2      Iris-setosa
# 66            5.6          3.0           4.5          1.5  Iris-versicolor
# 24            4.8          3.4           1.9          0.2      Iris-setosa
# 131           7.9          3.8           6.4          2.0   Iris-virginica
# 124           6.7          3.3           5.7          2.1   Iris-virginica
# 0             5.1          3.5           1.4          0.2      Iris-setosa

# %%
sns.pairplot(flower)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(flower,hue='species')
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
